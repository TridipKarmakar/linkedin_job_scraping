# %%
# Import Packages
from selenium import webdriver
import time
import pandas as pd
import os
import json


from selenium.webdriver.support.select import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException

# %%
url1 = 'https://www.linkedin.com/jobs/search/?currentJobId=3745271444&f_TPR=r86400&f_WT=2&geoId=103644278&keywords=python%20developer&location=United%20States&origin=JOB_SEARCH_PAGE_JOB_FILTER&refresh=true'

# %%
driver = webdriver.Chrome()
driver.get(url1)
driver.implicitly_wait(10)

# %%
n = driver.find_elements(By.CLASS_NAME,'results-context-header__job-count')[0].text
n

try :
    no_of_jobs = int(n.replace(',', '').replace('+', ''))
except :
    no_of_jobs = int(n)
print(no_of_jobs)
# Out:
# 185

# %%
per_page_jobs = 20 # assuming that no of job listed in a single page is 20
no_of_scrolls = int(no_of_jobs / per_page_jobs) 

i=2
while i <= no_of_scrolls: 
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    i+=1
    
    try :
        x = driver.find_element(By.XPATH,"//button[@aria-label='See more jobs']")
        driver.execute_script("arguments[0].click();",x)
        time.sleep(3)
    except :
        pass
        time.sleep(4)

# %%
compnay_name = []
for j in range(no_of_jobs) :
    try :
        company = driver.find_elements(By.CLASS_NAME,'base-search-card__subtitle')[j].text
        compnay_name.append(company)
    except IndexError :
        print("done")
# Out:
# done
# done

# %%
job_title = []
for j in range(no_of_jobs) :
    try :
        title = driver.find_elements(By.CLASS_NAME,'base-search-card__title')[j].text
        job_title.append(title)
    except IndexError :
        print("done")
# Out:
# done
# done

# %%
job_link = []
link = driver.find_elements(By.CLASS_NAME,'base-card__full-link')
for m in (link) :
        job_link.append(m.get_attribute('href'))
link_final = pd.DataFrame(job_link,columns= ['Job Link']  )

# %%
company_final = pd.DataFrame(compnay_name,columns= ['Company Name']  )

# %%
title_final = pd.DataFrame(job_title,columns= ['Job Title']  )

# %%
final = company_final.join(title_final)

# %%
final_com = final.join(link_final)

# %%
final_com
# Out:
#                                 Company Name  \
# 0                               MHK TECH INC
# 1                          Zortech Solutions
# 2                                    TekJobs
# 3    RE/MAX Town & Country - The Ailion Team
# 4                                  A2Zxperts
# ..                                       ...
# 178                                     Aha!
# 179                                     Aha!
# 180                      Booz Allen Hamilton
# 181                                     Aha!
# 182                                     Aha!
#
#                                              Job Title  \
# 0                                 Sr. Python Developer
# 1                              Senior Python Developer
# 2                                 Python AWS Developer
# 3                                        Web Developer
# 4                                   Fullstack Engineer
# ..                                                 ...
# 178                         Sr. Ruby on Rails Engineer
# 179                         Sr. Ruby on Rails Engineer
# 180             Cloud Infrastructure Architect, Senior
# 181  Sr. Security Engineer (Ruby on Rails experienc...
# 182  Sr. Security Engineer (Ruby on Rails experienc...
#
#                                               Job Link
# 0    https://www.linkedin.com/jobs/view/sr-python-d...
# 1    https://www.linkedin.com/jobs/view/senior-pyth...
# 2    https://www.linkedin.com/jobs/view/python-aws-...
# 3    https://www.linkedin.com/jobs/view/web-develop...
# 4    https://www.linkedin.com/jobs/view/fullstack-e...
# ..                                                 ...
# 178  https://www.linkedin.com/jobs/view/sr-ruby-on-...
# 179  https://www.linkedin.com/jobs/view/sr-ruby-on-...
# 180  https://www.linkedin.com/jobs/view/cloud-infra...
# 181  https://www.linkedin.com/jobs/view/sr-security...
# 182  https://www.linkedin.com/jobs/view/sr-security...
#
# [183 rows x 3 columns]

# %%
#final_com.to_csv('1linkeding_job_details')

# %%
# Getting Job description

# %%
job_desc = []

for l in job_link :
    driver.get(l)
    try :
        job_Script = driver.find_element(By.CSS_SELECTOR,'.show-more-less-html__markup--clamp-after-5')
        job_comment = job_Script.text
        if job_comment.find("\n") :
            final_comment = job_comment.replace("\\n", "\n")
        else :
            pass
        job_desc.append(final_comment)    
        time.sleep(4)
    except NoSuchElementException:
        job_desc.append("The specified element was not found on the page.")
        pass
        time.sleep(4)

print(job_desc)
# Out:
# ['Senior Python Software Engineer - We are looking for someone who has worked previously as a Python Software Engineer to help us build and grow our data platform. We are working to build optimized ingestion, ETL/ELT and reporting platforms designed to deliver insights with minimal latency.\nThe ideal candidate should possess most of the following:\n• Knowledge of OOP principals\n• Knowledge of Design Patterns\n• Ability to write advanced coding structures such as decorators, context managers, etc\n• Knowledge of python best coding practices (such as PEP8)\n• Knowledge of pandas, threading, regular expressions\nNice to have skills:\n• Prior experience coding in Airflow\n• Prior experience with Kafka\n• Prior experience building APIs\n• Prior experience with test driven development\n• Prior experience with AWS, Kubernetes, Docker', 'Hello Professionals, We have urgent requirement for Senior Python Developer\n\nPlease have a look at the below job description, if interested please share your updated resume, email me, pavan@zortechsolutions.ca or share any References.', 'Python AWS Developer\nRemote\nThe role is 100% focused on back-end development.\n\nJob Responsibilities:\nYou must be:', 'We are looking for an experienced and enthusiastic Web Developer to join The Ailion Team at RE/MAX Town and Country. In this position, you will have the opportunity to work remotely, helping to create and maintain data-driven websites and applications for our clients. From front-end programming to back-end database management, you will use your technical skills and creativity to ensure that our websites are up-to-date, interactive, and optimized for search engines. You will receive competitive pay, flexible hours, and opportunities to grow and learn professionally. If you have a passion for web development and take pride in your work, we would love to hear from you.\n\nCompensation: $5 - $15 hourly', "Our Direct Client is looking for a Fullstack Engineer (w2/full time/)\n\nTitle: FullStack Engineer\n\nLocation: Remote\n\nType: Remote,Direct hire\n\n\n\nAre highly proficient with Laravel with at least 4+ years of development experience\n\nAre proficient with React able to own new features end-to-end\n\nExperience building SaaS applications.\n\nSelf-starter mentality and highly driven.\n\nExcellent communication and collaboration skills.\n\nPrevious remote work experience with distributed Dev team members.\n\nThorough knowledge, experience, and understanding with full stack development.\n\n\n\nDevOps experience is a big plus! Any direct work with AWS with EBCLI, Docker, Kubernetes, nginx, linux distros will surely grab our team's attention.\n\nDirect experience with B2B Saas Applications.\n\nPreference to those with experience in the restaurant or food service industry.\n\nOpen to occasional evening and weekend work.\n\nFeel free to reach Priya at priya@a2zxperts.com", "The Role\n\nApploi is hiring a Senior Backend Engineer to join our fast-paced, innovative, and remote-first environment. You will work with a team of engineers responsible for improving and maintaining Apploi’s core products. Working directly with product managers and your peers in an agile environment, you will develop an engineering strategy focused on creating intuitive, scalable software for healthcare providers.\n\nOur ideal candidate is a passionate problem-solver and strong collaborator who is transparent about progress on tasks, seeks feedback early and often, and inspires their colleagues to do better.\n\nWe believe in a highly collaborative and supportive team culture where ideas are celebrated, so it's important that you are not only an accomplished Senior Backend Engineer but also a critical and strategic thinker—and, of course, an exceptional team player. We are dedicated to ensuring this opportunity not only aligns with Apploi’s goals, but also contributes to your career path. Thank you for considering this role!\n\nWho You Are\n\nYou are a strong backend engineer wi ...

# %%
job_desce = pd.DataFrame(job_desc,columns= ['Description']  )
final_com = final_com.join(job_desce)
final_com
# Out:
#                                 Company Name  \
# 0                               MHK TECH INC
# 1                          Zortech Solutions
# 2                                    TekJobs
# 3    RE/MAX Town & Country - The Ailion Team
# 4                                  A2Zxperts
# ..                                       ...
# 178                                     Aha!
# 179                                     Aha!
# 180                      Booz Allen Hamilton
# 181                                     Aha!
# 182                                     Aha!
#
#                                              Job Title  \
# 0                                 Sr. Python Developer
# 1                              Senior Python Developer
# 2                                 Python AWS Developer
# 3                                        Web Developer
# 4                                   Fullstack Engineer
# ..                                                 ...
# 178                         Sr. Ruby on Rails Engineer
# 179                         Sr. Ruby on Rails Engineer
# 180             Cloud Infrastructure Architect, Senior
# 181  Sr. Security Engineer (Ruby on Rails experienc...
# 182  Sr. Security Engineer (Ruby on Rails experienc...
#
#                                               Job Link  \
# 0    https://www.linkedin.com/jobs/view/sr-python-d...
# 1    https://www.linkedin.com/jobs/view/senior-pyth...
# 2    https://www.linkedin.com/jobs/view/python-aws-...
# 3    https://www.linkedin.com/jobs/view/web-develop...
# 4    https://www.linkedin.com/jobs/view/fullstack-e...
# ..                                                 ...
# 178  https://www.linkedin.com/jobs/view/sr-ruby-on-...
# 179  https://www.linkedin.com/jobs/view/sr-ruby-on-...
# 180  https://www.linkedin.com/jobs/view/cloud-infra...
# 181  https://www.linkedin.com/jobs/view/sr-security...
# 182  https://www.linkedin.com/jobs/view/sr-security...
#
#                                            description  \
# 0    Senior Python Software Engineer - We are looki...
# 1    Hello Professionals, We have urgent requiremen...
# 2    Python AWS Developer\nRemote\nThe role is 100%...
# 3    We are looking for an experienced and enthusia...
# 4    Our Direct Client is looking for a Fullstack E...
# ..                                                 ...
# 178  Aha! helps companies build lovable software. W...
# 179  Aha! helps companies build lovable software. W...
# 180  Job Number: R0184125\n\nCloud Infrastructure A...
# 181  Aha! helps companies build lovable software. W...
# 182  Aha! helps companies build lovable software. W...
#
#                                            Description
# 0    Senior Python Software Engineer - We are looki...
# 1    Hello Professionals, We have urgent requiremen...
# 2    Python AWS Developer\nRemote\nThe role is 100%...
# 3    We are looking for an experienced and enthusia...
# 4    Our Direct Client is looking for a Fullstack E...
# ..                                                 ...
# 178  Aha! helps companies build lovable software. W...
# 179  Aha! helps companies build lovable software. W...
# 180  Job Number: R0184125\n\nCloud Infrastructure A...
# 181  Aha! helps companies build lovable software. W...
# 182  Aha! helps companies build lovable software. W...
#
# [183 rows x 5 columns]

# %%
k = final_com['description'][0]

# %%
text = "This is a text with\nnewlines."
text_with_newlines = k.replace("\\n", "\n")
print(text_with_newlines)
# Out:
# This is a remote position.
#
# Job Title: Python Developer (Entry Level)
#
# Location of client: Tampa, Florida
#
# Full-Time
#
# $66,000 - $76,000 per annum
#
# Minimum 1 year of project experience
#
# HireMeFast is a leading staffing and recruitment agency specializing in connecting businesses with top-tier talent across various industries. Our mission is to bridge the gap between exceptional candidates and organizations needing their skills, expertise, and unique qualities.
#
# Our team of experienced and dedicated recruitment specialists utilizes innovative sourcing strategies, and a vast network to identify and attract top talent. We conduct comprehensive procedures to ensure that only the most qualified candidates are presented to our clients.
#
# Job Description:
#
# In this role, you will work closely with senior developers and other cross-functional teams to develop and maintain high-quality Python applications. As an (Entry Level) Python Developer, you will have the opportunity to learn and grow your skills while contributing to exciting projects.
#
# Responsibilities:
#
#
#
# Requirements:
#
#
#
# Nice to have:
#
#
#
# Special Benefits you will love:
#
#
#
#
#
# At HireMeFast, we understand that finding the right individuals to join your team is crucial for success and growth of your organization. We are committed to streamlining the hiring process for our clients, ensuring they have access to a diverse pool of highly qualified candidates who are a perfect fit for their specific needs.

# %%
job_posting = """This is a remote position.

Job Title: Python Developer (Entry Level)

Location of client: Tampa, Florida

Full-Time

$66,000 - $76,000 per annum

Minimum 1 year of project experience

HireMeFast is a leading staffing and recruitment agency specializing in connecting businesses with top-tier talent across various industries. Our mission is to bridge the gap between exceptional candidates and organizations needing their skills, expertise, and unique qualities.

Our team of experienced and dedicated recruitment specialists utilizes innovative sourcing strategies, and a vast network to identify and attract top talent. We conduct comprehensive procedures to ensure that only the most qualified candidates are presented to our clients.

Job Description:

In this role, you will work closely with senior developers and other cross-functional teams to develop and maintain high-quality Python applications. As an (Entry Level) Python Developer, you will have the opportunity to learn and grow your skills while contributing to exciting projects.

Responsibilities:



Requirements:



Nice to have:



Special Benefits you will love:



At HireMeFast, we understand that finding the right individuals to join your team is crucial for success and growth of your organization. We are committed to streamlining the hiring process for our clients, ensuring they have access to a diverse pool of highly qualified candidates who are a perfect fit for their specific needs.
"""

lines = [line.strip() for line in job_posting.splitlines() if line.strip()]
cleaned_text = '\n'.join(lines)
print(cleaned_text)
# Out:
# This is a remote position.
# Job Title: Python Developer (Entry Level)
# Location of client: Tampa, Florida
# Full-Time
# $66,000 - $76,000 per annum
# Minimum 1 year of project experience
# HireMeFast is a leading staffing and recruitment agency specializing in connecting businesses with top-tier talent across various industries. Our mission is to bridge the gap between exceptional candidates and organizations needing their skills, expertise, and unique qualities.
# Our team of experienced and dedicated recruitment specialists utilizes innovative sourcing strategies, and a vast network to identify and attract top talent. We conduct comprehensive procedures to ensure that only the most qualified candidates are presented to our clients.
# Job Description:
# In this role, you will work closely with senior developers and other cross-functional teams to develop and maintain high-quality Python applications. As an (Entry Level) Python Developer, you will have the opportunity to learn and grow your skills while contributing to exciting projects.
# Responsibilities:
# Requirements:
# Nice to have:
# Special Benefits you will love:
# At HireMeFast, we understand that finding the right individuals to join your team is crucial for success and growth of your organization. We are committed to streamlining the hiring process for our clients, ensuring they have access to a diverse pool of highly qualified candidates who are a perfect fit for their specific needs.

# %%
l = []
for i in job_posting.splitlines() : 
    l.append(i)
print(l)
# Out:
# ['This is a remote position.', '', 'Job Title: Python Developer (Entry Level)', '', 'Location of client: Tampa, Florida', '', 'Full-Time', '', '$66,000 - $76,000 per annum', '', 'Minimum 1 year of project experience', '', 'HireMeFast is a leading staffing and recruitment agency specializing in connecting businesses with top-tier talent across various industries. Our mission is to bridge the gap between exceptional candidates and organizations needing their skills, expertise, and unique qualities.', '', 'Our team of experienced and dedicated recruitment specialists utilizes innovative sourcing strategies, and a vast network to identify and attract top talent. We conduct comprehensive procedures to ensure that only the most qualified candidates are presented to our clients.', '', 'Job Description:', '', 'In this role, you will work closely with senior developers and other cross-functional teams to develop and maintain high-quality Python applications. As an (Entry Level) Python Developer, you will have the opportunity to learn and grow your skills while contributing to exciting projects.', '', 'Responsibilities:', '', '', '', 'Requirements:', '', '', '', 'Nice to have:', '', '', '', 'Special Benefits you will love:', '', '', '', 'At HireMeFast, we understand that finding the right individuals to join your team is crucial for success and growth of your organization. We are committed to streamlining the hiring process for our clients, ensuring they have access to a diverse pool of highly qualified candidates who are a perfect fit for their specific needs.']

# %%
if l[2].strip() :
    print(l[2])
    print(1)
else:
    print(0)
# Out:
# Job Title: Python Developer (Entry Level)
# 1

# %%
final_job_dec = []
for i in job_desc :
    job_desc = i.replace("\\n", "\n")
    final_job_dec.append(i)

# %%
final_job_dec
# Out:
# ['.']
